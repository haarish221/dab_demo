# %%
dbutils.widgets.text("catalogue_name", "assetsbundles")

# %%
catalogue_name = dbutils.widgets.get("catalogue_name")

# %%
df = spark.sql(f'select * from {catalogue_name}.information_schema.columns')
display(df)
